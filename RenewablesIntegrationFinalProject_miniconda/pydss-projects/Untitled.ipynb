# %%
from pydss.apps.data_viewer import DataViewer
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pydss.apps.data_viewer import DataViewer
#       2 from IPython.display import display, HTML, clear_output
#       3 display(HTML("<style>.container { width:100% !important; }</style>"))
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/apps/data_viewer.py:19
#      15     print("plotly is required to run the DataViewer. Please run 'pip install plotly'")
#      16     sys.exit(1)
# ---> 19 from pydss.pydss_results import PyDssResults
#      22 class DataViewer:
#      23     """Provides a UI for viewing pydss results."""
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/pydss_results.py:16
#      14 from pydss.element_options import ElementOptions
#      15 from pydss.exceptions import InvalidParameter
# ---> 16 from pydss.pydss_project import PyDssProject, RUN_SIMULATION_FILENAME
#      17 from pydss.reports.reports import Reports, REPORTS_DIR
#      18 from pydss.utils.dataframe_utils import read_dataframe, write_dataframe
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/pydss_project.py:22
#      15 from pydss.common import PROJECT_TAR, PROJECT_ZIP, CONTROLLER_TYPES, \
#      16     SIMULATION_SETTINGS_FILENAME, DEFAULT_SIMULATION_SETTINGS_FILE, \
#      17     ControllerType, ExportMode, SnapshotTimePointSelectionMode, MONTE_CARLO_SETTINGS_FILENAME,\
#      18     filename_from_enum, DEFAULT_MONTE_CARLO_SETTINGS_FILE,\
#      19     SUBSCRIPTIONS_FILENAME, DEFAULT_SUBSCRIPTIONS_FILE, OPENDSS_MASTER_FILENAME, \
#      20     RUN_SIMULATION_FILENAME
#      21 from pydss.exceptions import InvalidParameter, InvalidConfiguration
# ---> 22 from pydss.pyDSS import instance
#      23 from pydss.pydss_fs_interface import PyDssFileSystemInterface, \
#      24     PyDssArchiveFileInterfaceBase, PyDssTarFileInterface, \
#      25     PyDssZipFileInterface, PROJECT_DIRECTORIES, \
#      26     SCENARIOS, STORE_FILENAME
#      27 from pydss.reports.reports import REPORTS_DIR
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/pyDSS.py:8
#       6 from pydss.common import RUN_SIMULATION_FILENAME
#       7 from pydss.exceptions import InvalidConfiguration
# ----> 8 from pydss.dssInstance import OpenDSS
#       9 from pydss.simulation_input_models import SimulationSettingsModel, dump_settings
#      10 from pydss.utils.utils import dump_data, load_data
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/dssInstance.py:14
#      12 from pydss.pyPostprocessor import pyPostprocess
#      13 import pydss.pyControllers as pyControllers
# ---> 14 from pydss import helics_interface as HI
#      15 from pydss.ResultData import ResultData
#      16 from pydss.dssCircuit import dssCircuit
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/pydss/helics_interface.py:4
#       2 from typing import List, Optional, Any, Union, Dict
#       3 from enum import Enum
# ----> 4 import helics
#       5 import os
#       6 import re
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/helics/__init__.py:2
#       1 # -*- coding: utf-8 -*-
# ----> 2 from .capi import *
#       3 from ._version import __version__
#       5 import atexit
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/helics/capi.py:27
#      23     def cast(_, val):
#      24         return val
# ---> 27 from . import _build
#      29 lib = _build.lib
#      30 ffi = _build.ffi
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/helics/_build.py:157
#     153                     raise Exception("Unable to load helics shared library")
#     154     return lib
# --> 157 lib = _load_library()
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/helics/_build.py:134, in _load_library()
#     132     if "helicsSharedLib." in file or "libhelics." in file and file.endswith(".so"):
#     133         logger.debug("dlopen helics library in {}".format(os.path.join(lib_folder, file)))
# --> 134         lib = ffi.dlopen(os.path.join(lib_folder, file))
#     135         break
#     136 else:
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/cffi/api.py:150, in FFI.dlopen(self, name, flags)
#     147     raise TypeError("dlopen(name): name must be a file name, None, "
#     148                     "or an already-opened 'void *' handle")
#     149 with self._lock:
# --> 150     lib, function_cache = _make_ffi_library(self, name, flags)
#     151     self._function_caches.append(function_cache)
#     152     self._libraries.append(lib)
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/cffi/api.py:834, in _make_ffi_library(ffi, libname, flags)
#     832 def _make_ffi_library(ffi, libname, flags):
#     833     backend = ffi._backend
# --> 834     backendlib = _load_backend_lib(backend, libname, flags)
#     835     #
#     836     def accessor_function(name):
#
# File ~/miniconda/envs/pydss/lib/python3.9/site-packages/cffi/api.py:830, in _load_backend_lib(backend, name, flags)
#     828         msg = "%s.  Additionally, %s" % (first_error, msg)
#     829     raise OSError(msg)
# --> 830 return backend.load_library(path, flags)
#
# OSError: cannot load library '/home/kory/miniconda/envs/pydss/lib/libhelics.so.3': /home/kory/miniconda/envs/pydss/lib/python3.9/site-packages/zmq/backend/cython/../../../../.././libstdc++.so.6: version `GLIBCXX_3.4.30' not found (required by /home/kory/miniconda/envs/pydss/lib/libhelics.so.3)

# %%
app = DataViewer(project_path="<my-project>")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 app = DataViewer(project_path="<my-project>")
#
# NameError: name 'DataViewer' is not defined

# %%
import helics
